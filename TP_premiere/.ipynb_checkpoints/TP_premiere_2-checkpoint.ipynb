# %% [markdown]
# # TP premiere n°2

# %%
def produit(x,y) :
    x_MA, y_MA, x_MB, y_MB = (-2-x), (0-y), (2-x), (0-y)
    return x_MA*x_MB + y_MA*y_MB

# %%
#produit(0,0)

# %%
import matplotlib.pyplot as pl
# %matplotlib  inline
def impact1(x,y):
    pl.axis([-5,5,-5,5])
    pl.grid()
    if produit(x,y) <= 0 :
        pl.plot(x,y,'red',marker=".")
    elif produit(x,y) <= 12 :
        pl.plot(x,y,'blue',marker=".")
    else :
        pl.plot(x,y,'green',marker=".")
    pl.show()

# %%
impact1(0,0)

# %%
impact1(3,2)

# %%
impact1(-4,4)

# %%
import random
def simulation(n) :
    r, b, v = 0, 0, 0
    pl.axis([-5.2,5.2,-5.2,5.2])
    pl.grid()
    for i in range(n) :
        x_M,y_M = random.uniform(-5,5), random.uniform(-5,5)
        # impact1(x_M,y_M)
        if produit(x_M,y_M) <= 0 :
            pl.plot(x_M,y_M,'red',marker=".")
            r = r + 1
        elif produit(x_M,y_M) <= 12 :
            pl.plot(x_M,y_M,'blue',marker=".")
            b = b + 1
        else :
            pl.plot(x_M,y_M,'green',marker=".")
            v = v + 1
    pl.show()
    print("")
    print(" Nbre d'impacts Rouge =", r,'\n', "Nbre d'impacts Blue =", b,'\n', "Nbre d'impacts Verte =", v)
    print("")

# %%
simulation(10000)
# Out:
#  Nbre d'impacts Rouge = 1252
#  Nbre d'impacts Blue = 3748
#  Nbre d'impacts Verte = 5000
