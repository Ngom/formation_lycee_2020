# %%
from IPython.display import  Video, YouTubeVideo, Image, IFrame # pour lire video, image et webapage.
Video("jupyter3.mp4",width = 600, height = 600) # Video locale
# Out:
# <video src="jupyter3.mp4" controls  width="600"  height="600">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
YouTubeVideo("NSiPeoDpwuI", width = 600, height = 400) # Video Youtube

# %%
Image('cible.png') # image locale, meme methode ppour l'image en ligne en donnant l'adresse.

# %% [markdown]
# La figure ci-haut nous montre les _impacts_ d'une cible colorée :
# $\overrightarrow{MA}\cdot \overrightarrow{MB} = x_{MA}\times y_{MA} + y_{MA}\times y_{MA}$ du **produit scalaire**.

# %% [markdown]
# # Commande linux sont disponible en '!' devant

# %%
# !ls
# Out:
# BaseMarkdown.ipynb  jupyter1.mp4  jupyter4.mp4
# cible.png	    jupyter2.mp4  montage_image_video.ipynb
# install_img1.png    jupyter3.mp4  PremierNotebook.ipynb

# %%
# !pwd
# Out:
# /home/elhadji/Desktop/formation_lycee_2020/Stage_Jupyter_2020/J1/Tutoriels

# %%
IFrame(src="http://acver.fr/gi8",width = 900,height = 400)
# Out:
#         <iframe
#             width="900"
#             height="400"
#             src="http://acver.fr/gi8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Réduire la taille de l'url ici

# %% [markdown]
# Sur Edu portail :
# https://edu-cas.ac-versailles.fr/cas/login?service=http%3a%2f%2facver.fr%2findex.php

# %%
# !anaconda-navigator
# Out:
# /home/elhadji/anaconda3/lib/python3.7/site-packages/anaconda_navigator/api/conda_api.py:1364: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f)
# 2020-03-06 20:54:13,845 - ERROR download_api._download:234
# Invalid url https://www.anaconda.com/wp-content/uploads/2018/05/Screen-Shot-2018-05-23-at-5.52.25-PM.png
#
# 2020-03-06 20:54:23,076 - ERROR download_api._download:234
# Invalid url https://www.anaconda.com/wp-content/uploads/2017/05/Webinar20-20Three20Ways20to20Move20your20Data20Science20Projects20to20Production.png
